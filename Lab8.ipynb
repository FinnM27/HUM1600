# %% [markdown]
# <a href="https://colab.research.google.com/github/FinnM27/HUM1600/blob/main/Lab8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Week 8 Lab
Beginner
Finnegan McDonough
UID: 01370067
"""


# Function to displa the menu
def display_menu():
  print("/nExpense Tracker Menu:")
  print("1. Add Expense")
  print("2. View Expenses")
  print("3. Edit Expense")
  print("4. Delete Expense")
  print("5. Exit")
  choice = input("Enter your choice (1/2/3/4/5):")
  return choice

# Function to add an expense
def add_expense():
  print("\n--- Add Expense ---")
  date = input("Enter date (YYYY-MM-DD):")
  category = input("Enter category:")
  description = input("Enter description:")
  amount = input("Enter amount:")

# Append the new expense to the expenses.csv file
with open('expenses.csv', 'a';) as file:
    File.write(f"{date}, {category}, {description}, {amount}\n")

print("Expense added successfully")


# Function to view all expenses
def view_expenses():
  print("\n--- Recorded Expenses ---")
    if not os.path.exists('expenses.csv') or os.path.getsize('expenses.csv') == 0:
            print("No expenses recorded.")
            return

      with open('expenses.csv' , 'r') as file:
            expenses = file.readlines()

  if not expenses:
    print("No expenses recorded.")
    else:
            for index, expense in enumerate(expenses, start = 1):
            date, category, description, amount = expense.strip().split(',')
              print(f"{index}. Date: {date}, Category: {category}, Description: {description}, Amount: ${amount}")

# Function to edit an expense
def edit_expense():
  print("\n--- Edit Expense ---")

if not os.path.exists('expenses.csv') or os.path.getsize('expenses.csv') == 0:
            print("No expenses recorded.")
            return

# View expenses first
with open('expenses.csv', 'r') as file:
            expenses = file.readlines()

# Display expenses and primt for selection
for index, expense in enumerate(expenses, start= 1):
  date, category, description, amount = expense.strip().split(",")
  print(f"{index}. Date: {date}, Category: {category}, Description: {description}, Amount: ${amoint}")
try:
    expense_num = int(input("Enter the number of the expense you want to edit:"))
    if expense_num < 1 or expense_num > len(expenses):
      print("Invalid choice.")
      return

# Get the selected expense
selected_expense = expense[expense_num - 1]
date, category, description, amount, = selected_expense.strip().split(',')
print(f"\nEditing Expense: {date}, {cateogry}, {description}, ${amount}")

# Prompt for new values (keep current value if empty)
new_date = input(f"Enter new date (press enter to keep '{date}'):") or date
new_category = input(f"Enter new cateogry (press enter to keep '{description}'):") or description
new_amount = (f"Enter new amount (press enter to keep '{amount}'):") or amount

# Update the expense in the list
expenses[expenses_num - 1]=
f"{new_date}, {new_cateogry}, {new_description}, {new_amount}\n"

# Save the updated expenses back to the file
with open('expenses.csv', 'w') as file:
  file.writelines(expenses)

  print("Expenses updated successfully")
  except ValueError:
    print("Invalid input. Please enter a valud number")

# Function to delete an expense
def delete_expense():
  print("\n--- Delete Expense ---")

  if not os.path.exists('expenses.csv') or os.path.getsize('expenses.csv') == 0:
    print("No expenses recorded.")
    return

# View expenses first
with open('expenses.csv' , 'r') as file:
  expenses = file.readlines()

# Display expenses and prompt for selection
for index, expense in enumerate(expenses, start = 1):
  date, category, description, amount = expense.strip().split(',')
  print(f"{index}. Date: {date}, Category: {category}, Description: {description}, Amount: ${amount} ")
  try:
    expense_num = int(input("Enter the number of the expense you want to delete:"))
    if expense_num < or expense_num > len(expenses):
      print("Invalid choice.")
      return

# Remove selected expense
expenses.pop(expense_num - 1)

# Save the updated expenses back to the file
with open('expenses.csv', 'w') as file:
  file.writelines(expenses)

  print("Expense deleted successfully")
  except ValueError:
    print("Invalid input. Please enter a valid number.")

# Main function to run the program
def expense_tracker():
  while True:
    choice = display_menu()

    if choice == '1':
      add_expense()
      elif choice == '2':
        view_expenses()
        elif choice == '3':
          edit_expense()
          elif choice == '4':
            delete_expense()
            elif choice == '5':
              print("Exiting the Expense Tracker. Goodbye")
              break
              print("Invalid choice. Please try again")

# Run the expense tracker program
if__name__=="__main__":
  expense_tracker()
# Out:
#   File "<tokenize>", line 42
#     with open('expenses.csv' , 'r') as file:
#     ^
# IndentationError: unindent does not match any outer indentation level
